# %% [markdown]
# 1. 나이가 20이상이면 성인, 미만이면 청소년으로 처리
# 2.  성인 남성입니다., 성인 여성입니다., 청소년 남성입니다. 청소년 여성입니다.
# 3. 남,여를 잘못 입력했을 시 '다시 입력해 주세요. [남, 여]'
# 4. 남 여를 판단, 이후 나이 판단해서 결과는 두개가 조인함수 써서 나오게 해보자. 이건 케이스를 다 써서 너무 길어.
#     - age 먼저 물어봐서 if 쓰고 성인, 청소년 여부 그 하위에 남,여 물어봐서 결과를 합치게(합치는건 어떤 방법 써야할까)
#     - 따로 따로 적용된 조건이 합쳐지는 방법이 있을까? 나중에 다 따로해서 별로인가?

# %%
age =int(input('나이: '))
gender = input('성별[남,여]:')

if gender == '남':
    if age >= 20:# pass # 이거뭐임 코드를 우선 오류가 안나오게 넘기는 것
        print('성인 남성입니다.')
    else:
        print('청소년 남성입니다.')

elif gender =='여' :
    if age >=20:
        print('성인 여성입니다.')
    else:
        print('청소년 여성입니다.')
else:
    print('다시 입력해 주세요.[남, 여]')
# Out:
# Running cells with 'cpython-3.12.13-windows-x86_64-none (3.12.13) (Python 3.12.13)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/katzm/AppData/Roaming/uv/python/cpython-3.12.13-windows-x86_64-none/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
age =int(input('나이: '))
gender = input('성별[남,여]:')

if gender =='여':
    print('여성')
elif gender=='남':
    print('남성')
else:
    print('다시 입력해 주세요. [남, 여]') #다시 입력하는 거면 포크레인인것도 출력 안해줘야지. 19세 포크레인이 뭐니

    if age >=20:
        print('성인')

    else :
        print('청소년')

print(age," ",gender,"입니다.")
        
#else:
#    print('다시 입력해 주세요.[남, 여]')
# Out:
# 다시 입력해 주세요. [남, 여]
# 청소년
# 19   포크레인 입니다.

# %% [markdown]
# ### 추가 문의 필요 사항
# 디렉토리 버전이 3.14 인데 vs 코드에서 커널은 3.12.13 으로 받은 상태
