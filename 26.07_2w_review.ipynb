# %% [markdown]
# ### 26.07.13_ 수업 진행 중 발생이슈

# %% [markdown]
# 2026-07-13 16:02:12.001 [info] > git fetch [606ms] 2026-07-13 16:02:12.050 [info] > git config --get commit.template [45ms] 2026-07-13 16:02:12.055 [info] > git for-each-ref --format=%(refname)%00%(upstream:short)%00%(objectname)%00%(upstream:track)%00%(upstream:remotename)%00%(upstream:remoteref) --ignore-case refs/heads/main refs/remotes/main [47ms] 2026-07-13 16:02:12.105 [info] > git for-each-ref --sort -committerdate --format %(refname)%00%(objectname)%00%(*objectname) [44ms] 2026-07-13 16:02:12.106 [info] > git status -z -uall [47ms] 2026-07-13 16:02:12.968 [info] > git log --oneline --cherry main...main@{upstream} -- [51ms] 2026-07-13 16:02:13.564 [info] > git pull --tags origin main [593ms] 2026-07-13 16:02:13.564 [info] From https://github.com/rupria/py-uv-workspace * branch main -> FETCH_HEAD 2026-07-13 16:02:44.854 [info] > git push origin main:main [31287ms] 2026-07-13 16:02:44.854 [info] remote: error: Trace: ca7e38383a1c8a4a0e1ca50fd5c5ec1f3772b41148bc7eeee0b7c833f9421b35 remote: error: See https://gh.io/lfs for more information. remote: error: File source/
# <br>
# <span style="color:red"> 소상공인시장진흥공단_상가(상권)정보_서울_202503(1).csv is 280.39 MB;
# this exceeds GitHub's file size limit of 100.00 MB remote: error: GH001: Large files detected. </span><br>
# You may want to try Git Large File Storage - https://git-lfs.github.com. To https://github.com/rupria/py-uv-workspace.git ! [remote rejected] main -> main (pre-receive hook declined) error: failed to push some refs to 'https://github.com/rupria/py-uv-workspace.git' 2026-07-13 16:02:44.905 [info] > git config --get commit.template [46ms] 2026-07-13 16:02:44.909 [info] > git for-each-ref --format=%(refname)%00%(upstream:short)%00%(objectname)%00%(upstream:track)%00%(upstream:remotename)%00%(upstream:remoteref) --ignore-case refs/heads/main refs/remotes/main [47ms] 2026-07-13 16:02:44.964 [info] > git status -z -uall [50ms] 2026-07-13 16:02:44.965 [info] > git for-each-ref --sort -committerdate --format %(refname)%00%(objectname)%00%(*objectname) [49ms] 2026-07-13 16:02:45.038 [info] > git config --get commit.template [65ms] 2026-07-13 16:02:45.086 [info] > git for-each-ref --format=%(refname)%00%(upstream:short)%00%(objectname)%00%(upstream:track)%00%(upstream:remotename)%00%(upstream:remoteref) --ignore-case refs/heads/main refs/remotes/main [108ms] 2026-07-13 16:02:45.156 [info] > git status -z -uall [65ms] 2026-07-13 16:02:45.159 [info] > git for-each-ref --sort -committerdate --format %(refname)%00%(objectname)%00%(*objectname) [64ms] 2026-07-13 16:03:17.625 [info] > git for-each-ref --format=%(refname)%00%(upstream:short)%00%(objectname)%00%(upstream:track)%00%(upstream:remotename)%00%(upstream:remoteref) --ignore-case refs/remotes/origin/main [42ms] 2026-07-13 16:03:17.691 [info] > git log --oneline --cherry main...main@{upstream} -- [60ms] 2026-07-13 16:03:18.537 [info] > git pull --tags origin main [840ms] 2026-07-13 16:03:18.537 [info] From https://github.com/rupria/py-uv-workspace * branch main -> FETCH_HEAD 2026-07-13 16:03:18.613 [info] > git config --get commit.template [71ms] 2026-07-13 16:03:18.619 [info] > git for-each-ref --format=%(refname)%00%(upstream:short)%00%(objectname)%00%(upstream:track)%00%(upstream:remotename)%00%(upstream:remoteref) --ignore-case refs/heads/main refs/remotes/main [72ms] 2026-07-13 16:03:18.693 [info] > git status -z -uall [70ms] 2026-07-13 16:03:18.697 [info] > git for-each-ref --sort -committerdate --format %(refname)%00%(objectname)%00%(*objectname) [72ms] 2026-07-13 16:03:28.325 [info] > git check-ignore -v -z --stdin [91ms] 2026-07-13 16:03:38.762 [info] > git check-ignore -v -z --stdin [43ms] 2026-07-13 16:03:41.927 [info] > git check-ignore -v -z --stdin [44ms]
